# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
from numpy.polynomial.polynomial import polyfit
import seaborn as sns
import calendar

import geopandas as gpd
from geopandas.tools import sjoin

# %%
df1999 = pd.read_csv('/Users/anjalidoney/Downloads/resale-flat-prices/resale-flat-prices-based-on-approval-date-1990-1999.csv')
df2012 = pd.read_csv('/Users/anjalidoney/Downloads/resale-flat-prices/resale-flat-prices-based-on-approval-date-2000-feb-2012.csv')
df2018 = pd.read_csv('/Users/anjalidoney/Downloads/resale-flat-prices/resale-flat-prices-based-on-registration-date-from-jan-2015-onwards.csv')
df2014 = pd.read_csv('/Users/anjalidoney/Downloads/resale-flat-prices/resale-flat-prices-based-on-registration-date-from-mar-2012-to-dec-2014.csv')

# %%
testdf = df2014.append(df2018)
testdf.head(5)
# Out:
#   block      flat_model flat_type  floor_area_sqm  lease_commence_date  \
# 0   172        Improved    2 ROOM            45.0                 1986
# 1   510        Improved    2 ROOM            44.0                 1980
# 2   610  New Generation    3 ROOM            68.0                 1980
# 3   474  New Generation    3 ROOM            67.0                 1984
# 4   604  New Generation    3 ROOM            67.0                 1980
#
#      month  remaining_lease  resale_price storey_range        street_name  \
# 0  2012-03              NaN      250000.0     06 TO 10   ANG MO KIO AVE 4
# 1  2012-03              NaN      265000.0     01 TO 05   ANG MO KIO AVE 8
# 2  2012-03              NaN      315000.0     06 TO 10   ANG MO KIO AVE 4
# 3  2012-03              NaN      320000.0     01 TO 05  ANG MO KIO AVE 10
# 4  2012-03              NaN      321000.0     06 TO 10   ANG MO KIO AVE 5
#
#          town
# 0  ANG MO KIO
# 1  ANG MO KIO
# 2  ANG MO KIO
# 3  ANG MO KIO
# 4  ANG MO KIO

# %%
df2018.head
# Out:
# <bound method NDFrame.head of          month        town  flat_type block        street_name storey_range  \
# 0      2015-01  ANG MO KIO     3 ROOM   174   ANG MO KIO AVE 4     07 TO 09
# 1      2015-01  ANG MO KIO     3 ROOM   541  ANG MO KIO AVE 10     01 TO 03
# 2      2015-01  ANG MO KIO     3 ROOM   163   ANG MO KIO AVE 4     01 TO 03
# 3      2015-01  ANG MO KIO     3 ROOM   446  ANG MO KIO AVE 10     01 TO 03
# 4      2015-01  ANG MO KIO     3 ROOM   557  ANG MO KIO AVE 10     07 TO 09
# 5      2015-01  ANG MO KIO     3 ROOM   603   ANG MO KIO AVE 5     07 TO 09
# 6      2015-01  ANG MO KIO     3 ROOM   709   ANG MO KIO AVE 8     01 TO 03
# 7      2015-01  ANG MO KIO     3 ROOM   333   ANG MO KIO AVE 1     01 TO 03
# 8      2015-01  ANG MO KIO     3 ROOM   109   ANG MO KIO AVE 4     01 TO 03
# 9      2015-01  ANG MO KIO     3 ROOM   564   ANG MO KIO AVE 3     13 TO 15
# 10     2015-01  ANG MO KIO     3 ROOM   218   ANG MO KIO AVE 1     07 TO 09
# ...

# %%
df2018.tail
# Out:
# <bound method NDFrame.tail of          month        town  flat_type block        street_name storey_range  \
# 0      2015-01  ANG MO KIO     3 ROOM   174   ANG MO KIO AVE 4     07 TO 09
# 1      2015-01  ANG MO KIO     3 ROOM   541  ANG MO KIO AVE 10     01 TO 03
# 2      2015-01  ANG MO KIO     3 ROOM   163   ANG MO KIO AVE 4     01 TO 03
# 3      2015-01  ANG MO KIO     3 ROOM   446  ANG MO KIO AVE 10     01 TO 03
# 4      2015-01  ANG MO KIO     3 ROOM   557  ANG MO KIO AVE 10     07 TO 09
# 5      2015-01  ANG MO KIO     3 ROOM   603   ANG MO KIO AVE 5     07 TO 09
# 6      2015-01  ANG MO KIO     3 ROOM   709   ANG MO KIO AVE 8     01 TO 03
# 7      2015-01  ANG MO KIO     3 ROOM   333   ANG MO KIO AVE 1     01 TO 03
# 8      2015-01  ANG MO KIO     3 ROOM   109   ANG MO KIO AVE 4     01 TO 03
# 9      2015-01  ANG MO KIO     3 ROOM   564   ANG MO KIO AVE 3     13 TO 15
# 10     2015-01  ANG MO KIO     3 ROOM   218   ANG MO KIO AVE 1     07 TO 09
# ...

# %%
df2014.dtypes
# Out:
# month                   object
# town                    object
# flat_type               object
# block                   object
# street_name             object
# storey_range            object
# floor_area_sqm         float64
# flat_model              object
# lease_commence_date      int64
# resale_price           float64
# dtype: object

# %%
df2018.street_name
# Out:
# 0         ANG MO KIO AVE 4
# 1        ANG MO KIO AVE 10
# 2         ANG MO KIO AVE 4
# 3        ANG MO KIO AVE 10
# 4        ANG MO KIO AVE 10
# 5         ANG MO KIO AVE 5
# 6         ANG MO KIO AVE 8
# 7         ANG MO KIO AVE 1
# 8         ANG MO KIO AVE 4
# 9         ANG MO KIO AVE 3
# 10        ANG MO KIO AVE 1
# 11       ANG MO KIO AVE 10
# 12        ANG MO KIO AVE 4
# 13       ANG MO KIO AVE 10
# 14       ANG MO KIO AVE 10
# 15       ANG MO KIO AVE 10
# 16        ANG MO KIO AVE 1
# 17       ANG MO KIO AVE 10
# 18        ANG MO KIO AVE 8
# 19        ANG MO KIO AVE 4
# 20        ANG MO KIO AVE 5
# 21       ANG MO KIO AVE 10
# 22       ANG MO KIO AVE 10
# 23        ANG MO KIO AVE 3
# 24        ANG MO KIO AVE 5
# 25        ANG MO KIO AVE 1
# 26        ANG MO KIO AVE 3
# 27        ANG MO KIO AVE 3
# 28        ANG MO KIO AVE 3
# 29        ANG MO KIO AVE 6
#                ...
# 65221         YISHUN ST 61
# 65222         YISHUN ST 61
# 65223         YISHUN ST 71
# ...

# %%
df2018.storey_range
# Out:
# 0        07 TO 09
# 1        01 TO 03
# 2        01 TO 03
# 3        01 TO 03
# 4        07 TO 09
# 5        07 TO 09
# 6        01 TO 03
# 7        01 TO 03
# 8        01 TO 03
# 9        13 TO 15
# 10       07 TO 09
# 11       10 TO 12
# 12       10 TO 12
# 13       07 TO 09
# 14       07 TO 09
# 15       07 TO 09
# 16       10 TO 12
# 17       01 TO 03
# 18       07 TO 09
# 19       07 TO 09
# 20       10 TO 12
# 21       10 TO 12
# 22       10 TO 12
# 23       10 TO 12
# 24       04 TO 06
# 25       04 TO 06
# 26       07 TO 09
# 27       07 TO 09
# 28       07 TO 09
# 29       07 TO 09
#            ...
# 65221    10 TO 12
# 65222    01 TO 03
# 65223    01 TO 03
# 65224    10 TO 12
# 65225    04 TO 06
# 65226    07 TO 09
# 65227    07 TO 09
# 65228    10 TO 12
# 65229    04 TO 06
# 65230    01 TO 03
# 65231    01 TO 03
# 65232    07 TO 09
# 65233    04 TO 06
# 65234    01 TO 03
# 65235    10 TO 12
# 65236    07 TO 09
# 65237    04 TO 06
# 65238    01 TO 03
# 65239    10 TO 12
# ...

# %%
df2014.dtypes
# Out:
# month                   object
# town                    object
# flat_type               object
# block                   object
# street_name             object
# storey_range            object
# floor_area_sqm         float64
# flat_model              object
# lease_commence_date      int64
# resale_price           float64
# dtype: object

# %%
df2012.dtypes
# Out:
# month                   object
# town                    object
# flat_type               object
# block                   object
# street_name             object
# storey_range            object
# floor_area_sqm         float64
# flat_model              object
# lease_commence_date      int64
# resale_price           float64
# dtype: object

# %%
df2018[['month','resale_price']]
# Out:
#          month  resale_price
# 0      2015-01      255000.0
# 1      2015-01      275000.0
# 2      2015-01      285000.0
# 3      2015-01      290000.0
# 4      2015-01      290000.0
# 5      2015-01      290000.0
# 6      2015-01      290000.0
# 7      2015-01      293000.0
# 8      2015-01      300000.0
# 9      2015-01      307500.0
# 10     2015-01      308000.0
# 11     2015-01      312000.0
# 12     2015-01      312000.0
# 13     2015-01      319000.0
# 14     2015-01      320000.0
# 15     2015-01      320000.0
# 16     2015-01      325000.0
# 17     2015-01      325000.0
# 18     2015-01      325000.0
# 19     2015-01      330000.0
# 20     2015-01      330000.0
# 21     2015-01      335000.0
# 22     2015-01      338000.0
# 23     2015-01      340000.0
# 24     2015-01      340000.0
# 25     2015-01      341000.0
# 26     2015-01      345000.0
# 27     2015-01      350000.0
# 28     2015-01      355000.0
# 29     2015-01      355000.0
# ...        ...           ...
# ...

# %%
df = df2018[['month','resale_price']]

# %%
df2018.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 65251 entries, 0 to 65250
# Data columns (total 11 columns):
# month                  65251 non-null object
# town                   65251 non-null object
# flat_type              65251 non-null object
# block                  65251 non-null object
# street_name            65251 non-null object
# storey_range           65251 non-null object
# floor_area_sqm         65251 non-null float64
# flat_model             65251 non-null object
# lease_commence_date    65251 non-null int64
# remaining_lease        65251 non-null int64
# resale_price           65251 non-null float64
# dtypes: float64(2), int64(2), object(7)
# memory usage: 5.5+ MB

# %%
df2018.isnull().values.any()
# Out:
# False

# %%
df2018.corr(method='pearson')
# Out:
#                      floor_area_sqm  lease_commence_date  remaining_lease  \
# floor_area_sqm             1.000000             0.339587         0.340287
# lease_commence_date        0.339587             1.000000         0.995742
# remaining_lease            0.340287             0.995742         1.000000
# resale_price               0.645778             0.354100         0.352230
#
#                      resale_price
# floor_area_sqm           0.645778
# lease_commence_date      0.354100
# remaining_lease          0.352230
# resale_price             1.000000

# %%
df2018.corr(method='spearman')
# Out:
#                      floor_area_sqm  lease_commence_date  remaining_lease  \
# floor_area_sqm             1.000000             0.385620         0.382072
# lease_commence_date        0.385620             1.000000         0.993809
# remaining_lease            0.382072             0.993809         1.000000
# resale_price               0.718885             0.405634         0.406735
#
#                      resale_price
# floor_area_sqm           0.718885
# lease_commence_date      0.405634
# remaining_lease          0.406735
# resale_price             1.000000

# %%
df2018.corr(method='pearson',min_periods=1).style.format("{:.2}").background_gradient(cmap=plt.get_cmap('coolwarm'))
# Out:
# <style  type="text/css" >
#     #T_dca02242_7947_11e8_9cb7_8c85907836b2row0_col0 {
#             background-color:  #b40426;
#         }    #T_dca02242_7947_11e8_9cb7_8c85907836b2row0_col1 {
#             background-color:  #3b4cc0;
#         }    #T_dca02242_7947_11e8_9cb7_8c85907836b2row0_col2 {
#             background-color:  #3b4cc0;
#         }    #T_dca02242_7947_11e8_9cb7_8c85907836b2row0_col3 {
#             background-color:  #d1dae9;
#         }    #T_dca02242_7947_11e8_9cb7_8c85907836b2row1_col0 {
#             background-color:  #3b4cc0;
#         }    #T_dca02242_7947_11e8_9cb7_8c85907836b2row1_col1 {
#             background-color:  #b40426;
#         }    #T_dca02242_7947_11e8_9cb7_8c85907836b2row1_col2 {
#             background-color:  #b50927;
#         }    #T_dca02242_7947_11e8_9cb7_8c85907836b2row1_col3 {
#             background-color:  #3b4cc0;
#         }    #T_dca02242_7947_11e8_9cb7_8c85907836b2row2_col0 {
#             background-color:  #3b4cc0;
# ...

# %%
plt.rcParams['figure.figsize'] = [16, 10]
plt.scatter(df2018.floor_area_sqm,df2018.resale_price,s=0.8)

b, m = polyfit(df2018.floor_area_sqm,df2018.resale_price, 1)

x = df2018.floor_area_sqm
plt.plot(x, b + m * x, '-')

plt.show()

# %%
sns.set(style="whitegrid", palette="muted")

df = df2018.pivot_table(index='town', columns='flat_model', values='resale_price', aggfunc=np.median)
sns.heatmap(df, annot=False, fmt=".1f")

plt.show()

# df = df2018[["floor_area_sqm","remaining_lease","resale_price"]]

# sns.heatmap(df.corr(), annot=True, fmt=".2f")

# %%
df = df2018[['floor_area_sqm','remaining_lease','resale_price']]
sns.heatmap(df.corr(), annot=True, fmt=".1f")
plt.show()

# %%
sns.stripplot(x="town", y="resale_price", data=df2018, jitter=True)
plt.show()

# %% [markdown]
# ## Converting Month Column to Month Names and Year

# %%
df2018.month
# Out:
# 0        2015-01
# 1        2015-01
# 2        2015-01
# 3        2015-01
# 4        2015-01
# 5        2015-01
# 6        2015-01
# 7        2015-01
# 8        2015-01
# 9        2015-01
# 10       2015-01
# 11       2015-01
# 12       2015-01
# 13       2015-01
# 14       2015-01
# 15       2015-01
# 16       2015-01
# 17       2015-01
# 18       2015-01
# 19       2015-01
# 20       2015-01
# 21       2015-01
# 22       2015-01
# 23       2015-01
# 24       2015-01
# 25       2015-01
# 26       2015-01
# 27       2015-01
# 28       2015-01
# 29       2015-01
#           ...
# 65221    2018-05
# 65222    2018-05
# 65223    2018-05
# 65224    2018-05
# 65225    2018-05
# 65226    2018-05
# 65227    2018-05
# 65228    2018-05
# 65229    2018-05
# 65230    2018-05
# 65231    2018-05
# 65232    2018-05
# 65233    2018-05
# 65234    2018-05
# 65235    2018-05
# 65236    2018-05
# 65237    2018-05
# 65238    2018-05
# 65239    2018-05
# 65240    2018-05
# 65241    2018-05
# ...

# %%
df = df2018
df['month'] = pd.to_datetime(df['month'])
df['month_number']= df.month.dt.month

# %%
df.tail(5)
# Out:
#            month    town  flat_type block     street_name storey_range  \
# 65246 2018-05-01  YISHUN  EXECUTIVE   791    YISHUN AVE 2     04 TO 06
# 65247 2018-05-01  YISHUN  EXECUTIVE   328  YISHUN RING RD     07 TO 09
# 65248 2018-05-01  YISHUN  EXECUTIVE   352  YISHUN RING RD     10 TO 12
# 65249 2018-05-01  YISHUN  EXECUTIVE   723    YISHUN ST 71     10 TO 12
# 65250 2018-05-01  YISHUN  EXECUTIVE   828    YISHUN ST 81     07 TO 09
#
#        floor_area_sqm  flat_model  lease_commence_date  remaining_lease  \
# 65246           141.0   Apartment                 1987               68
# 65247           142.0   Apartment                 1988               69
# 65248           154.0  Maisonette                 1988               69
# 65249           142.0   Apartment                 1986               67
# 65250           142.0   Apartment                 1988               68
#
#        resale_price  month_number
# 65246      535000.0             5
# 65247      528888.0             5
# ...

# %%
df['month_name'] = df['month_number'].apply(lambda x: calendar.month_name[x])

df.tail(5)
# Out:
#            month    town  flat_type block     street_name storey_range  \
# 65246 2018-05-01  YISHUN  EXECUTIVE   791    YISHUN AVE 2     04 TO 06
# 65247 2018-05-01  YISHUN  EXECUTIVE   328  YISHUN RING RD     07 TO 09
# 65248 2018-05-01  YISHUN  EXECUTIVE   352  YISHUN RING RD     10 TO 12
# 65249 2018-05-01  YISHUN  EXECUTIVE   723    YISHUN ST 71     10 TO 12
# 65250 2018-05-01  YISHUN  EXECUTIVE   828    YISHUN ST 81     07 TO 09
#
#        floor_area_sqm  flat_model  lease_commence_date  remaining_lease  \
# 65246           141.0   Apartment                 1987               68
# 65247           142.0   Apartment                 1988               69
# 65248           154.0  Maisonette                 1988               69
# 65249           142.0   Apartment                 1986               67
# 65250           142.0   Apartment                 1988               68
#
#        resale_price  month_number month_name
# 65246      535000.0             5        May
# ...

# %%
df['year']= df.month.dt.year
df.tail(5)
# Out:
#            month    town  flat_type block     street_name storey_range  \
# 65246 2018-05-01  YISHUN  EXECUTIVE   791    YISHUN AVE 2     04 TO 06
# 65247 2018-05-01  YISHUN  EXECUTIVE   328  YISHUN RING RD     07 TO 09
# 65248 2018-05-01  YISHUN  EXECUTIVE   352  YISHUN RING RD     10 TO 12
# 65249 2018-05-01  YISHUN  EXECUTIVE   723    YISHUN ST 71     10 TO 12
# 65250 2018-05-01  YISHUN  EXECUTIVE   828    YISHUN ST 81     07 TO 09
#
#        floor_area_sqm  flat_model  lease_commence_date  remaining_lease  \
# 65246           141.0   Apartment                 1987               68
# 65247           142.0   Apartment                 1988               69
# 65248           154.0  Maisonette                 1988               69
# 65249           142.0   Apartment                 1986               67
# 65250           142.0   Apartment                 1988               68
#
#        resale_price  month_number month_name  year
# 65246      535000.0             5        May  2018
# ...

# %%
df[['month','lease_commence_date']].head(5)
# Out:
#        month  lease_commence_date
# 0 2015-01-01                 1986
# 1 2015-01-01                 1981
# 2 2015-01-01                 1980
# 3 2015-01-01                 1979
# 4 2015-01-01                 1980

# %%
df.lease_commence_date + df.remaining_lease
# Out:
# 0        2056
# 1        2046
# 2        2044
# 3        2042
# 4        2044
# 5        2044
# 6        2044
# 7        2046
# 8        2040
# 9        2054
# 10       2036
# 11       2044
# 12       2046
# 13       2042
# 14       2042
# 15       2044
# 16       2046
# 17       2042
# 18       2044
# 19       2054
# 20       2046
# 21       2042
# 22       2044
# 23       2038
# 24       2046
# 25       2046
# 26       2040
# 27       2042
# 28       2054
# 29       2044
#          ...
# 65221    2055
# 65222    2057
# 65223    2055
# 65224    2051
# 65225    2051
# 65226    2049
# 65227    2049
# 65228    2056
# 65229    2057
# 65230    2057
# 65231    2055
# 65232    2066
# 65233    2057
# 65234    2055
# 65235    2055
# 65236    2055
# 65237    2054
# 65238    2054
# 65239    2055
# 65240    2050
# 65241    2051
# 65242    2051
# 65243    2051
# 65244    2056
# 65245    2056
# 65246    2055
# 65247    2057
# 65248    2057
# 65249    2053
# 65250    2056
# ...

# %%
df[df['lease_commence_date']==1984]
# Out:
#            month           town  flat_type block          street_name  \
# 118   2015-01-01          BEDOK     4 ROOM   724   BEDOK RESERVOIR RD
# 148   2015-01-01         BISHAN     3 ROOM   308            SHUNFU RD
# 160   2015-01-01         BISHAN     4 ROOM   302            SHUNFU RD
# 164   2015-01-01         BISHAN     5 ROOM   310            SHUNFU RD
# 180   2015-01-01    BUKIT BATOK     3 ROOM   217       BT BATOK ST 21
# 189   2015-01-01    BUKIT BATOK     3 ROOM   146  BT BATOK WEST AVE 6
# 197   2015-01-01    BUKIT BATOK     3 ROOM   164       BT BATOK ST 11
# 198   2015-01-01    BUKIT BATOK     3 ROOM   167  BT BATOK WEST AVE 8
# 207   2015-01-01    BUKIT BATOK     4 ROOM   138  BT BATOK WEST AVE 6
# 211   2015-01-01    BUKIT BATOK     4 ROOM   113  BT BATOK WEST AVE 6
# 213   2015-01-01    BUKIT BATOK     4 ROOM   164       BT BATOK ST 11
# 216   2015-01-01    BUKIT BATOK     4 ROOM   165  BT BATOK WEST AVE 8
# ...

# %%
df[['flat_type','flat_model']].head(5)
# Out:
#   flat_type      flat_model
# 0    3 ROOM        Improved
# 1    3 ROOM  New Generation
# 2    3 ROOM  New Generation
# 3    3 ROOM  New Generation
# 4    3 ROOM  New Generation

# %%
df.flat_type.unique()
# Out:
# array(['3 ROOM', '4 ROOM', '5 ROOM', '2 ROOM', 'EXECUTIVE', '1 ROOM',
#        'MULTI-GENERATION'], dtype=object)

# %%
df.flat_model.unique()
# Out:
# array(['Improved', 'New Generation', 'Model A', 'Standard', 'Simplified',
#        'Premium Apartment', 'Maisonette', 'Apartment', 'Model A2',
#        'Type S1', 'Type S2', 'Adjoined flat', 'Terrace', 'DBSS',
#        'Model A-Maisonette', 'Premium Maisonette', 'Multi Generation',
#        'Premium Apartment Loft', 'Improved-Maisonette', '2-room',
#        'Premium Apartment.'], dtype=object)

# %%
bedroom_dict = {'1 ROOM':1, '2 ROOM': 1, '3 ROOM':2, '4 ROOM':3, '5 ROOM':3, 'EXECUTIVE':3, 'MULTI-GENERATION':4}
bathroom_dict = {'1 ROOM':1, '2 ROOM': 1, '3 ROOM':2, '4 ROOM':2, '5 ROOM':2, 'EXECUTIVE':2, 'MULTI-GENERATION':3}
df['bedrooms'] = df['flat_type'].map(bedroom_dict)
df['bathrooms'] = df['flat_type'].map(bathroom_dict)
df.head(5)
# Out:
#        month        town flat_type block        street_name storey_range  \
# 0 2015-01-01  ANG MO KIO    3 ROOM   174   ANG MO KIO AVE 4     07 TO 09
# 1 2015-01-01  ANG MO KIO    3 ROOM   541  ANG MO KIO AVE 10     01 TO 03
# 2 2015-01-01  ANG MO KIO    3 ROOM   163   ANG MO KIO AVE 4     01 TO 03
# 3 2015-01-01  ANG MO KIO    3 ROOM   446  ANG MO KIO AVE 10     01 TO 03
# 4 2015-01-01  ANG MO KIO    3 ROOM   557  ANG MO KIO AVE 10     07 TO 09
#
#    floor_area_sqm      flat_model  lease_commence_date  remaining_lease  \
# 0            60.0        Improved                 1986               70
# 1            68.0  New Generation                 1981               65
# 2            69.0  New Generation                 1980               64
# 3            68.0  New Generation                 1979               63
# 4            68.0  New Generation                 1980               64
#
#    resale_price  month_number month_name  year  bedrooms  bathrooms
# ...

# %% [markdown]
# ## Town Population Dataset

# %%
townpop = pd.read_csv('/Users/anjalidoney/Downloads/estimated-resident-population-living-in-hdb-flats/estimated-resident-population-in-hdb-flats-by-town.csv')

# %%
townpop.head(5)
# Out:
#    financial_year town_or_estate  population
# 0            2008     Ang Mo Kio      148200
# 1            2008          Bedok      197900
# 2            2008         Bishan       66500
# 3            2008    Bukit Batok      109100
# 4            2008    Bukit Merah      140600

# %% [markdown]
# ### Town population dataset only contains data from 2008 to 2016

# %%
testdf['month'] = pd.to_datetime(testdf['month'])
testdf['month_number']= testdf.month.dt.month
testdf['month_name'] = testdf['month_number'].apply(lambda x: calendar.month_name[x])
testdf['year']= testdf.month.dt.year
testdf.tail(5)
# Out:
#       block  flat_model  flat_type  floor_area_sqm  lease_commence_date  \
# 65246   791   Apartment  EXECUTIVE           141.0                 1987
# 65247   328   Apartment  EXECUTIVE           142.0                 1988
# 65248   352  Maisonette  EXECUTIVE           154.0                 1988
# 65249   723   Apartment  EXECUTIVE           142.0                 1986
# 65250   828   Apartment  EXECUTIVE           142.0                 1988
#
#            month  remaining_lease  resale_price storey_range     street_name  \
# 65246 2018-05-01             68.0      535000.0     04 TO 06    YISHUN AVE 2
# 65247 2018-05-01             69.0      528888.0     07 TO 09  YISHUN RING RD
# 65248 2018-05-01             69.0      535000.0     10 TO 12  YISHUN RING RD
# 65249 2018-05-01             67.0      582888.0     10 TO 12    YISHUN ST 71
# 65250 2018-05-01             68.0      658000.0     07 TO 09    YISHUN ST 81
#
#          town  month_number month_name  year
# ...

# %%
testdf['bedrooms'] = testdf['flat_type'].map(bedroom_dict)
testdf['bathrooms'] = testdf['flat_type'].map(bathroom_dict)

testdf.tail(5)
# Out:
#       block  flat_model  flat_type  floor_area_sqm  lease_commence_date  \
# 65246   791   Apartment  EXECUTIVE           141.0                 1987
# 65247   328   Apartment  EXECUTIVE           142.0                 1988
# 65248   352  Maisonette  EXECUTIVE           154.0                 1988
# 65249   723   Apartment  EXECUTIVE           142.0                 1986
# 65250   828   Apartment  EXECUTIVE           142.0                 1988
#
#            month  remaining_lease  resale_price storey_range     street_name  \
# 65246 2018-05-01             68.0      535000.0     04 TO 06    YISHUN AVE 2
# 65247 2018-05-01             69.0      528888.0     07 TO 09  YISHUN RING RD
# 65248 2018-05-01             69.0      535000.0     10 TO 12  YISHUN RING RD
# 65249 2018-05-01             67.0      582888.0     10 TO 12    YISHUN ST 71
# 65250 2018-05-01             68.0      658000.0     07 TO 09    YISHUN ST 81
#
#          town  month_number month_name  year  bedrooms  bathrooms
# ...

# %%
df2014.head(5)
# Out:
#      month        town flat_type block        street_name storey_range  \
# 0  2012-03  ANG MO KIO    2 ROOM   172   ANG MO KIO AVE 4     06 TO 10
# 1  2012-03  ANG MO KIO    2 ROOM   510   ANG MO KIO AVE 8     01 TO 05
# 2  2012-03  ANG MO KIO    3 ROOM   610   ANG MO KIO AVE 4     06 TO 10
# 3  2012-03  ANG MO KIO    3 ROOM   474  ANG MO KIO AVE 10     01 TO 05
# 4  2012-03  ANG MO KIO    3 ROOM   604   ANG MO KIO AVE 5     06 TO 10
#
#    floor_area_sqm      flat_model  lease_commence_date  resale_price
# 0            45.0        Improved                 1986      250000.0
# 1            44.0        Improved                 1980      265000.0
# 2            68.0  New Generation                 1980      315000.0
# 3            67.0  New Generation                 1984      320000.0
# 4            67.0  New Generation                 1980      321000.0

# %%
testdf["townyear"] = testdf["town"] + testdf["year"].map(str)
testdf.head(5)
# Out:
#   block      flat_model flat_type  floor_area_sqm  lease_commence_date  \
# 0   172        Improved    2 ROOM            45.0                 1986
# 1   510        Improved    2 ROOM            44.0                 1980
# 2   610  New Generation    3 ROOM            68.0                 1980
# 3   474  New Generation    3 ROOM            67.0                 1984
# 4   604  New Generation    3 ROOM            67.0                 1980
#
#        month  remaining_lease  resale_price storey_range        street_name  \
# 0 2012-03-01              NaN      250000.0     06 TO 10   ANG MO KIO AVE 4
# 1 2012-03-01              NaN      265000.0     01 TO 05   ANG MO KIO AVE 8
# 2 2012-03-01              NaN      315000.0     06 TO 10   ANG MO KIO AVE 4
# 3 2012-03-01              NaN      320000.0     01 TO 05  ANG MO KIO AVE 10
# 4 2012-03-01              NaN      321000.0     06 TO 10   ANG MO KIO AVE 5
#
#          town  month_number month_name  year  bedrooms  bathrooms  \
# ...

# %%
townpop["townyear"] = townpop["town_or_estate"] + townpop["financial_year"].map(str)
townpop.head(5)
# Out:
#    financial_year town_or_estate  population         townyear
# 0            2008     Ang Mo Kio      148200   Ang Mo Kio2008
# 1            2008          Bedok      197900        Bedok2008
# 2            2008         Bishan       66500       Bishan2008
# 3            2008    Bukit Batok      109100  Bukit Batok2008
# 4            2008    Bukit Merah      140600  Bukit Merah2008

# %%
testdf.shape
# Out:
# (117454, 17)

# %%
testdf.townyear.to_string
townpop.townyear.to_string
# Out:
# <bound method Series.to_string of 0           Ang Mo Kio2008
# 1                Bedok2008
# 2               Bishan2008
# 3          Bukit Batok2008
# 4          Bukit Merah2008
# 5        Bukit Panjang2008
# 6          Bukit Timah2008
# 7        Choa Chu Kang2008
# 8         Central Area2008
# 9             Clementi2008
# 10             Geylang2008
# 11             Hougang2008
# 12         Jurong East2008
# 13         Jurong West2008
# 14     Kallang/Whampoa2008
# 15       Marine Parade2008
# 16           Pasir Ris2008
# 17             Punggol2008
# 18          Queenstown2008
# 19           Sembawang2008
# 20            Sengkang2008
# 21           Serangoon2008
# 22            Tampines2008
# 23           Toa Payoh2008
# 24           Woodlands2008
# 25              Yishun2008
# 26               Total2008
# 27          Ang Mo Kio2009
# 28               Bedok2009
# 29              Bishan2009
#               ...
# 213          Woodlands2015
# 214             Yishun2015
# ...

# %%
townpop['townyear'] = townpop['townyear'].map(lambda x: str(x).upper())
townpop.head(5)
# Out:
#    financial_year town_or_estate  population         townyear
# 0            2008     Ang Mo Kio      148200   ANG MO KIO2008
# 1            2008          Bedok      197900        BEDOK2008
# 2            2008         Bishan       66500       BISHAN2008
# 3            2008    Bukit Batok      109100  BUKIT BATOK2008
# 4            2008    Bukit Merah      140600  BUKIT MERAH2008

# %%
checkdf = testdf.merge(right=townpop, how='left', on="townyear")
checkdf.head(5)
# Out:
#   block      flat_model flat_type  floor_area_sqm  lease_commence_date  \
# 0   172        Improved    2 ROOM            45.0                 1986
# 1   510        Improved    2 ROOM            44.0                 1980
# 2   610  New Generation    3 ROOM            68.0                 1980
# 3   474  New Generation    3 ROOM            67.0                 1984
# 4   604  New Generation    3 ROOM            67.0                 1980
#
#        month  remaining_lease  resale_price storey_range        street_name  \
# 0 2012-03-01              NaN      250000.0     06 TO 10   ANG MO KIO AVE 4
# 1 2012-03-01              NaN      265000.0     01 TO 05   ANG MO KIO AVE 8
# 2 2012-03-01              NaN      315000.0     06 TO 10   ANG MO KIO AVE 4
# 3 2012-03-01              NaN      320000.0     01 TO 05  ANG MO KIO AVE 10
# 4 2012-03-01              NaN      321000.0     06 TO 10   ANG MO KIO AVE 5
#
#          town  month_number month_name  year  bedrooms  bathrooms  \
# ...

# %%
checkdf.drop(['townyear', 'financial_year','town_or_estate'], axis=1, inplace=True)

# %%
checkdf.head(5)
# Out:
#   block      flat_model flat_type  floor_area_sqm  lease_commence_date  \
# 0   172        Improved    2 ROOM            45.0                 1986
# 1   510        Improved    2 ROOM            44.0                 1980
# 2   610  New Generation    3 ROOM            68.0                 1980
# 3   474  New Generation    3 ROOM            67.0                 1984
# 4   604  New Generation    3 ROOM            67.0                 1980
#
#        month  remaining_lease  resale_price storey_range        street_name  \
# 0 2012-03-01              NaN      250000.0     06 TO 10   ANG MO KIO AVE 4
# 1 2012-03-01              NaN      265000.0     01 TO 05   ANG MO KIO AVE 8
# 2 2012-03-01              NaN      315000.0     06 TO 10   ANG MO KIO AVE 4
# 3 2012-03-01              NaN      320000.0     01 TO 05  ANG MO KIO AVE 10
# 4 2012-03-01              NaN      321000.0     06 TO 10   ANG MO KIO AVE 5
#
#          town  month_number month_name  year  bedrooms  bathrooms  population
# ...

# %%
plt.scatter(checkdf.population,checkdf.resale_price,s=0.8)

# b, m = polyfit(checkdf.resale_price,checkdf.population, 1)

# x = checkdf.population
# plt.plot(x, b + m * x, '-')

plt.show()

# %%
townsize = pd.read_csv('/Users/anjalidoney/Downloads/land-area-and-dwelling-units-by-town/land-area-and-dwelling-units-by-town.csv')

# %%
townsize.head(5)
# Out:
#    financial_year         town total_land_area  residential_land_area  \
# 0            2008   Ang Mo Kio             638                    283
# 1            2008        Bedok             937                    408
# 2            2008       Bishan             690                    172
# 3            2008  Bukit Batok             785                    291
# 4            2008  Bukit Merah             858                    312
#
#    dwelling_units_under_management  projected_ultimate_dwelling_units
# 0                            48069                              58000
# 1                            59929                              74000
# 2                            19367                              32000
# 3                            31731                              47000
# 4                            50247                              68000

# %%
townsize['townyear'] = townsize['town'] + townsize['financial_year'].map(str)
townsize['townyear'] = townpop['townyear'].map(lambda x: str(x).upper())
townsize.head(5)
# Out:
#    financial_year         town total_land_area  residential_land_area  \
# 0            2008   Ang Mo Kio             638                    283
# 1            2008        Bedok             937                    408
# 2            2008       Bishan             690                    172
# 3            2008  Bukit Batok             785                    291
# 4            2008  Bukit Merah             858                    312
#
#    dwelling_units_under_management  projected_ultimate_dwelling_units  \
# 0                            48069                              58000
# 1                            59929                              74000
# 2                            19367                              32000
# 3                            31731                              47000
# 4                            50247                              68000
#
#           townyear
# 0   ANG MO KIO2008
# 1        BEDOK2008
# 2       BISHAN2008
# 3  BUKIT BATOK2008
# 4  BUKIT MERAH2008

# %%
checkdf["townyear"] = checkdf["town"] + checkdf["year"].map(str)
checkdf2 = checkdf.merge(right=townsize[['townyear','residential_land_area']], how='left', on="townyear")

# %%
checkdf2.head(5)
# Out:
#   block      flat_model flat_type  floor_area_sqm  lease_commence_date  \
# 0   172        Improved    2 ROOM            45.0                 1986
# 1   510        Improved    2 ROOM            44.0                 1980
# 2   610  New Generation    3 ROOM            68.0                 1980
# 3   474  New Generation    3 ROOM            67.0                 1984
# 4   604  New Generation    3 ROOM            67.0                 1980
#
#        month  remaining_lease  resale_price storey_range        street_name  \
# 0 2012-03-01              NaN      250000.0     06 TO 10   ANG MO KIO AVE 4
# 1 2012-03-01              NaN      265000.0     01 TO 05   ANG MO KIO AVE 8
# 2 2012-03-01              NaN      315000.0     06 TO 10   ANG MO KIO AVE 4
# 3 2012-03-01              NaN      320000.0     01 TO 05  ANG MO KIO AVE 10
# 4 2012-03-01              NaN      321000.0     06 TO 10   ANG MO KIO AVE 5
#
#          town  month_number month_name  year  bedrooms  bathrooms  population  \
# ...

# %%
checkdf2['popdensity'] = checkdf2.population/checkdf2.residential_land_area

# %%
checkdf2.head(5)
# Out:
#   block      flat_model flat_type  floor_area_sqm  lease_commence_date  \
# 0   172        Improved    2 ROOM            45.0                 1986
# 1   510        Improved    2 ROOM            44.0                 1980
# 2   610  New Generation    3 ROOM            68.0                 1980
# 3   474  New Generation    3 ROOM            67.0                 1984
# 4   604  New Generation    3 ROOM            67.0                 1980
#
#        month  remaining_lease  resale_price storey_range        street_name  \
# 0 2012-03-01              NaN      250000.0     06 TO 10   ANG MO KIO AVE 4
# 1 2012-03-01              NaN      265000.0     01 TO 05   ANG MO KIO AVE 8
# 2 2012-03-01              NaN      315000.0     06 TO 10   ANG MO KIO AVE 4
# 3 2012-03-01              NaN      320000.0     01 TO 05  ANG MO KIO AVE 10
# 4 2012-03-01              NaN      321000.0     06 TO 10   ANG MO KIO AVE 5
#
#          town  month_number month_name  year  bedrooms  bathrooms  population  \
# ...

# %%
plt.scatter(checkdf2.popdensity,checkdf2.resale_price,s=0.8)
plt.show()

# %%
checkdf3 = checkdf.merge(right=townsize[['townyear','total_land_area']], how='left', on="townyear")
#checkdf3['popdensity'] = checkdf3.population / checkdf3.total_land_area
checkdf3.head(5)
# Out:
#   block      flat_model flat_type  floor_area_sqm  lease_commence_date  \
# 0   172        Improved    2 ROOM            45.0                 1986
# 1   510        Improved    2 ROOM            44.0                 1980
# 2   610  New Generation    3 ROOM            68.0                 1980
# 3   474  New Generation    3 ROOM            67.0                 1984
# 4   604  New Generation    3 ROOM            67.0                 1980
#
#        month  remaining_lease  resale_price storey_range        street_name  \
# 0 2012-03-01              NaN      250000.0     06 TO 10   ANG MO KIO AVE 4
# 1 2012-03-01              NaN      265000.0     01 TO 05   ANG MO KIO AVE 8
# 2 2012-03-01              NaN      315000.0     06 TO 10   ANG MO KIO AVE 4
# 3 2012-03-01              NaN      320000.0     01 TO 05  ANG MO KIO AVE 10
# 4 2012-03-01              NaN      321000.0     06 TO 10   ANG MO KIO AVE 5
#
#          town  month_number month_name  year  bedrooms  bathrooms  population  \
# ...

# %%
checkdf3.total_land_area.isnull().values.any()
# Out:
# True

# %%
checkdf3[checkdf3.total_land_area.isnull()]
# Out:
#        block      flat_model  flat_type  floor_area_sqm  lease_commence_date  \
# 69983    406        Improved     2 ROOM            44.0                 1979
# 69984    116        Improved     2 ROOM            44.0                 1978
# 69985    170        Improved     3 ROOM            60.0                 1986
# 69986    560  New Generation     3 ROOM            67.0                 1980
# 69987    258  New Generation     3 ROOM            73.0                 1977
# 69988    639  New Generation     3 ROOM            68.0                 1980
# 69989    538  New Generation     3 ROOM            68.0                 1980
# 69990    419  New Generation     3 ROOM            74.0                 1979
# 69991    435  New Generation     3 ROOM            67.0                 1979
# 69992    180  New Generation     3 ROOM            68.0                 1981
# 69993    444  New Generation     3 ROOM            67.0                 1979
# ...

# %%
checkdf3 = checkdf3.dropna(subset=['total_land_area'])

checkdf3.head(5)
# Out:
#   block      flat_model flat_type  floor_area_sqm  lease_commence_date  \
# 0   172        Improved    2 ROOM            45.0                 1986
# 1   510        Improved    2 ROOM            44.0                 1980
# 2   610  New Generation    3 ROOM            68.0                 1980
# 3   474  New Generation    3 ROOM            67.0                 1984
# 4   604  New Generation    3 ROOM            67.0                 1980
#
#        month  remaining_lease  resale_price storey_range        street_name  \
# 0 2012-03-01              NaN      250000.0     06 TO 10   ANG MO KIO AVE 4
# 1 2012-03-01              NaN      265000.0     01 TO 05   ANG MO KIO AVE 8
# 2 2012-03-01              NaN      315000.0     06 TO 10   ANG MO KIO AVE 4
# 3 2012-03-01              NaN      320000.0     01 TO 05  ANG MO KIO AVE 10
# 4 2012-03-01              NaN      321000.0     06 TO 10   ANG MO KIO AVE 5
#
#          town  month_number month_name  year  bedrooms  bathrooms  population  \
# ...

# %%
checkdf3[checkdf3.total_land_area.isnull()]
# Out:
# Empty DataFrame
# Columns: [block, flat_model, flat_type, floor_area_sqm, lease_commence_date, month, remaining_lease, resale_price, storey_range, street_name, town, month_number, month_name, year, bedrooms, bathrooms, population, townyear, total_land_area]
# Index: []

# %%
pd.to_numeric(checkdf3['population'])

checkdf4 = checkdf3[checkdf3['total_land_area']!='na']
#pd.to_numeric(checkdf3['total_land_area'])
#checkdf4['popdensity'] = checkdf4.population/checkdf4.total_land_area
checkdf4[checkdf4['total_land_area']=='na']
# Out:
# Empty DataFrame
# Columns: [block, flat_model, flat_type, floor_area_sqm, lease_commence_date, month, remaining_lease, resale_price, storey_range, street_name, town, month_number, month_name, year, bedrooms, bathrooms, population, townyear, total_land_area]
# Index: []

# %%
# pd.to_integer(checkdf4['population'])
# pd.to_integer(checkdf4['total_land_area'])

# checkdf4['population'] = checkdf4.population.astype(int,copy=False)
# checkdf4['total_land_area'] = checkdf4.total_land_area.astype(int,copy=False)

#checkd4['popdensity'] = checkdf4['population']/checkdf4['total_land_area']

checkdf4.head(5)
# Out:
#   block      flat_model flat_type  floor_area_sqm  lease_commence_date  \
# 0   172        Improved    2 ROOM            45.0                 1986
# 1   510        Improved    2 ROOM            44.0                 1980
# 2   610  New Generation    3 ROOM            68.0                 1980
# 3   474  New Generation    3 ROOM            67.0                 1984
# 4   604  New Generation    3 ROOM            67.0                 1980
#
#        month  remaining_lease  resale_price storey_range        street_name  \
# 0 2012-03-01              NaN      250000.0     06 TO 10   ANG MO KIO AVE 4
# 1 2012-03-01              NaN      265000.0     01 TO 05   ANG MO KIO AVE 8
# 2 2012-03-01              NaN      315000.0     06 TO 10   ANG MO KIO AVE 4
# 3 2012-03-01              NaN      320000.0     01 TO 05  ANG MO KIO AVE 10
# 4 2012-03-01              NaN      321000.0     06 TO 10   ANG MO KIO AVE 5
#
#          town  month_number month_name  year  bedrooms  bathrooms  population  \
# ...

# %%
checkdf4.dtypes
# Out:
# block                          object
# flat_model                     object
# flat_type                      object
# floor_area_sqm                float64
# lease_commence_date             int64
# month                  datetime64[ns]
# remaining_lease               float64
# resale_price                  float64
# storey_range                   object
# street_name                    object
# town                           object
# month_number                    int64
# month_name                     object
# year                            int64
# bedrooms                        int64
# bathrooms                       int64
# population                    float64
# townyear                       object
# total_land_area                object
# dtype: object

# %%
#checkdf4['total_land_area'] = pd.to_numeric(checkdf4['total_land_area'])

#checkdf4['total_land_area'] = pd.to_numeric(checkdf4['total_land_area'].str.replace(' ', '').str.replace(',', '.'))
#checkdf4.head(5)
checkdf4.dtypes
# Out:
# block                          object
# flat_model                     object
# flat_type                      object
# floor_area_sqm                float64
# lease_commence_date             int64
# month                  datetime64[ns]
# remaining_lease               float64
# resale_price                  float64
# storey_range                   object
# street_name                    object
# town                           object
# month_number                    int64
# month_name                     object
# year                            int64
# bedrooms                        int64
# bathrooms                       int64
# population                    float64
# townyear                       object
# total_land_area                 int64
# dtype: object

# %%
checkdf4['popdensity'] = checkdf4['population']/checkdf4['total_land_area']
# Out:
# /Users/anjalidoney/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.

# %%
checkdf4.dtypes
# Out:
# block                          object
# flat_model                     object
# flat_type                      object
# floor_area_sqm                float64
# lease_commence_date             int64
# month                  datetime64[ns]
# remaining_lease               float64
# resale_price                  float64
# storey_range                   object
# street_name                    object
# town                           object
# month_number                    int64
# month_name                     object
# year                            int64
# bedrooms                        int64
# bathrooms                       int64
# population                    float64
# townyear                       object
# total_land_area                 int64
# popdensity                    float64
# dtype: object

# %%
checkdf4.head(5)
# Out:
#   block      flat_model flat_type  floor_area_sqm  lease_commence_date  \
# 0   172        Improved    2 ROOM            45.0                 1986
# 1   510        Improved    2 ROOM            44.0                 1980
# 2   610  New Generation    3 ROOM            68.0                 1980
# 3   474  New Generation    3 ROOM            67.0                 1984
# 4   604  New Generation    3 ROOM            67.0                 1980
#
#        month  remaining_lease  resale_price storey_range        street_name  \
# 0 2012-03-01              NaN      250000.0     06 TO 10   ANG MO KIO AVE 4
# 1 2012-03-01              NaN      265000.0     01 TO 05   ANG MO KIO AVE 8
# 2 2012-03-01              NaN      315000.0     06 TO 10   ANG MO KIO AVE 4
# 3 2012-03-01              NaN      320000.0     01 TO 05  ANG MO KIO AVE 10
# 4 2012-03-01              NaN      321000.0     06 TO 10   ANG MO KIO AVE 5
#
#          town  month_number month_name  year  bedrooms  bathrooms  population  \
# ...

# %%
plt.scatter(checkdf4.popdensity,checkdf4.resale_price,s=0.8)
plt.show()

# %% [markdown]
# ### Observation: There does not seem to be a strong correlation with population or population density, except for range and bounds.

# %% [markdown]
# ## Looking at the effects of number of metro stations in a town on resale price

# %%
testdf.head(5)
# Out:
#   block      flat_model flat_type  floor_area_sqm  lease_commence_date  \
# 0   172        Improved    2 ROOM            45.0                 1986
# 1   510        Improved    2 ROOM            44.0                 1980
# 2   610  New Generation    3 ROOM            68.0                 1980
# 3   474  New Generation    3 ROOM            67.0                 1984
# 4   604  New Generation    3 ROOM            67.0                 1980
#
#        month  remaining_lease  resale_price storey_range        street_name  \
# 0 2012-03-01              NaN      250000.0     06 TO 10   ANG MO KIO AVE 4
# 1 2012-03-01              NaN      265000.0     01 TO 05   ANG MO KIO AVE 8
# 2 2012-03-01              NaN      315000.0     06 TO 10   ANG MO KIO AVE 4
# 3 2012-03-01              NaN      320000.0     01 TO 05  ANG MO KIO AVE 10
# 4 2012-03-01              NaN      321000.0     06 TO 10   ANG MO KIO AVE 5
#
#          town  month_number month_name  year  bedrooms  bathrooms  \
# ...

# %%
testdf.town.unique()
# Out:
# array(['ANG MO KIO', 'BEDOK', 'BISHAN', 'BUKIT BATOK', 'BUKIT MERAH',
#        'BUKIT PANJANG', 'BUKIT TIMAH', 'CENTRAL AREA', 'CHOA CHU KANG',
#        'CLEMENTI', 'GEYLANG', 'HOUGANG', 'JURONG EAST', 'JURONG WEST',
#        'KALLANG/WHAMPOA', 'MARINE PARADE', 'PASIR RIS', 'PUNGGOL',
#        'QUEENSTOWN', 'SEMBAWANG', 'SENGKANG', 'SERANGOON', 'TAMPINES',
#        'TOA PAYOH', 'WOODLANDS', 'YISHUN'], dtype=object)

# %%
len(testdf.town.unique())
# Out:
# 26

# %%
import shapefile as shp

sf = shp.Reader("/Users/anjalidoney/Downloads/TrainStation_Oct2017/MRTLRTStnPtt.shp")

plt.figure()
for shape in sf.shapeRecords():
    x = [i[0] for i in shape.shape.points[:]]
    y = [i[1] for i in shape.shape.points[:]]
    plt.plot(x,y)
plt.show()

# %%
gdf = gpd.read_file('/Users/anjalidoney/Downloads/TrainStation_Oct2017/MRTLRTStnPtt.shp')
print(gdf)
# Out:
#      OBJECTID                     STN_NAME       STN_NO  \
# 0           1            EUNOS MRT STATION          EW7
# 1           2   CHINESE GARDEN MRT STATION         EW25
# 2           3           KHATIB MRT STATION         NS14
# 3           4           KRANJI MRT STATION          NS7
# 4           5          REDHILL MRT STATION         EW18
# 5           6          YEW TEE MRT STATION          NS5
# 6           7          PIONEER MRT STATION         EW28
# 7           8     COMMONWEALTH MRT STATION         EW20
# 8           9       PAYA LEBAR MRT STATION          EW8
# 9          10            SIMEI MRT STATION          EW3
# 10         11         TAMPINES MRT STATION          EW2
# 11         12        ADMIRALTY MRT STATION         NS10
# 12         13           YISHUN MRT STATION         NS13
# 13         14        PASIR RIS MRT STATION          EW1
# 14         15         CLEMENTI MRT STATION         EW23
# 15         16         ALJUNIED MRT STATION          EW9
# ...

# %%
#%matplotlib inline
gdf.plot()

# %%
gdf2 = gpd.read_file('/Users/anjalidoney/Downloads/sdcp-landed-housing-area/sdcp-landed-housing-area-shp/G_MP08_LH_PL.shp')
print(gdf2)
# Out:
#      OBJECTID  UNIQUE_ID    BLD_HT           TYPE           INC_CRC  \
# 0           1        499  2-STOREY   MIXED LANDED  549C334AA43BC4DA
# 1           2        369  2-STOREY   MIXED LANDED  EF223E8354292A4B
# 2           3        509  3-STOREY   MIXED LANDED  500636A0933E5282
# 3           4        510  3-STOREY   MIXED LANDED  060365C86B4448C0
# 4           5        289  3-STOREY   MIXED LANDED  D3362180ED14B4C7
# 5           6        140  3-STOREY   MIXED LANDED  72DA0E8B805B24F8
# 6           7        292  3-STOREY   MIXED LANDED  8363262210559AB6
# 7           8        287  2-STOREY   MIXED LANDED  43C7896B590452B8
# 8           9        272  2-STOREY   MIXED LANDED  44B13F26B1349D28
# 9          10        416  3-STOREY   MIXED LANDED  DA4E4440B08DF33A
# 10         11        491  3-STOREY   MIXED LANDED  5835E1342B7E64FE
# 11         12         20  2-STOREY   MIXED LANDED  C46470CD90910103
# 12         13        481  2-STOREY   MIXED LANDED  6F7CC1FA069DC50C
# ...

# %%
gdf2.plot()

# %%
plt.rcParams['figure.figsize'] = [16, 10]
base = gdf2.plot(color='white', edgecolor='black')
gdf.plot(ax=base, marker='o', color='red', markersize=5)

# %%
singmap = gpd.read_file('/Users/anjalidoney/Downloads/gadm36_SGP_shp/gadm36_SGP_0.shp')
print(singmap)
# Out:
#   GID_0     NAME_0                                           geometry
# 0   SGP  Singapore  (POLYGON ((103.73278046 1.17611098, 103.733055...

# %%
singmap.plot()

# %%
base = singmap.plot()
#gdf2.plot(ax=base,color='green', edgecolor='black')
gdf.plot(ax=base, marker='o', color='red', markersize=5)

# %%
townmap = gpd.read_file('/Users/anjalidoney/Downloads/master-plan-2014-planning-area-boundary-web/master-plan-2014-planning-area-boundary-web-shp/MP14_PLNG_AREA_WEB_PL.shp')
townmap.plot()

# %%
#base = singmap.plot()
#townmap.plot(ax=base,color='green',edgecolor='black')
base = townmap.plot()
gdf.plot(ax=base, marker='*', color='yellow', markersize=15)

# %%
print(townmap)
# Out:
#     OBJECTID               PLN_AREA_N PLN_AREA_C CA_IND           REGION_N  \
# 0          1                   BISHAN         BS      N     CENTRAL REGION
# 1          2              BUKIT BATOK         BK      N        WEST REGION
# 2          3              BUKIT MERAH         BM      N     CENTRAL REGION
# 3          4            BUKIT PANJANG         BP      N        WEST REGION
# 4          5              BUKIT TIMAH         BT      N     CENTRAL REGION
# 5          6  CENTRAL WATER CATCHMENT         CC      N       NORTH REGION
# 6          7                   CHANGI         CH      N        EAST REGION
# 7          8               CHANGI BAY         CB      N        EAST REGION
# 8          9            CHOA CHU KANG         CK      N        WEST REGION
# 9         10                 CLEMENTI         CL      N        WEST REGION
# 10        11                  GEYLANG         GL      N     CENTRAL REGION
# ...

# %%
checkdf2.head(5)
# Out:
#   block      flat_model flat_type  floor_area_sqm  lease_commence_date  \
# 0   172        Improved    2 ROOM            45.0                 1986
# 1   510        Improved    2 ROOM            44.0                 1980
# 2   610  New Generation    3 ROOM            68.0                 1980
# 3   474  New Generation    3 ROOM            67.0                 1984
# 4   604  New Generation    3 ROOM            67.0                 1980
#
#        month  remaining_lease  resale_price storey_range        street_name  \
# 0 2012-03-01              NaN      250000.0     06 TO 10   ANG MO KIO AVE 4
# 1 2012-03-01              NaN      265000.0     01 TO 05   ANG MO KIO AVE 8
# 2 2012-03-01              NaN      315000.0     06 TO 10   ANG MO KIO AVE 4
# 3 2012-03-01              NaN      320000.0     01 TO 05  ANG MO KIO AVE 10
# 4 2012-03-01              NaN      321000.0     06 TO 10   ANG MO KIO AVE 5
#
#          town  month_number month_name  year  bedrooms  bathrooms  population  \
# ...

# %%
mapdf = checkdf2.groupby('town',as_index=False).agg({'resale_price': 'median', 'popdensity': 'median', 'residential_land_area': 'max'})
mapdf
# Out:
#                town  resale_price   popdensity  residential_land_area
# 0        ANG MO KIO     371000.00   750.500000                  480.0
# 1             BEDOK     388000.00   504.271357                  549.0
# 2            BISHAN     589444.00   165.491184                  422.0
# 3       BUKIT BATOK     375000.00   540.952381                  480.0
# 4       BUKIT MERAH     560000.00   369.346734                  549.0
# 5     BUKIT PANJANG     420000.00   478.629032                  397.0
# 6       BUKIT TIMAH     699000.00    28.865979                  480.0
# 7      CENTRAL AREA     502000.00   162.380952                  219.0
# 8     CHOA CHU KANG     408710.88   385.406699                  500.0
# 9          CLEMENTI     408000.00   232.573290                  525.0
# 10          GEYLANG     370000.00   225.358852                  439.0
# 11          HOUGANG     418000.00  1044.186047                  219.0
# ...

# %%
mapdf.dtypes
# Out:
# town             object
# resale_price    float64
# popdensity      float64
# dtype: object

# %%
t1 = checkdf2[checkdf2['town']=='ANG MO KIO']
t1.resale_price.median()
# Out:
# 371000.0

# %%
#print(townmap)
townmap.tail(5)
# Out:
#     OBJECTID       PLN_AREA_N PLN_AREA_C CA_IND        REGION_N REGION_C  \
# 50        51           OUTRAM         OT      Y  CENTRAL REGION       CR
# 51        52     RIVER VALLEY         RV      Y  CENTRAL REGION       CR
# 52        53           ROCHOR         RC      Y  CENTRAL REGION       CR
# 53        54  SINGAPORE RIVER         SR      Y  CENTRAL REGION       CR
# 54        55     STRAITS VIEW         SV      Y  CENTRAL REGION       CR
#
#              INC_CRC  FMEL_UPD_D      X_ADDR      Y_ADDR   SHAPE_Leng  \
# 50  736C77537EA35E27  2014-12-05  28972.9577  29477.4886  6158.958333
# 51  3873927C9F28D311  2014-12-05  28072.9131  31156.9405  6500.525518
# 52  56597B444C0B3106  2014-12-05  30219.3193  31843.5189  7849.959032
# 53  6E975674F87A9B7E  2014-12-05  28878.2147  30279.8445  6831.130979
# 54  214517996521BE9C  2014-12-05  30832.9017  28194.0843  5277.760827
#
#       SHAPE_Area                                           geometry
# ...

# %%
merged = townmap.merge(mapdf,how='left', left_on='PLN_AREA_N', right_on='town')
merged.describe()
# Out:
#        OBJECTID        X_ADDR        Y_ADDR     SHAPE_Leng    SHAPE_Area  \
# count  55.00000     55.000000     55.000000      55.000000  5.500000e+01
# mean   28.00000  27626.514455  36003.895435   20852.206381  1.421718e+07
# std    16.02082   9376.383074   5846.945642   17766.545772  1.483919e+07
# min     1.00000   5687.971100  25069.982700    4385.926738  8.302731e+05
# 25%    14.50000  21930.252050  31596.094450   13238.119200  6.630102e+06
# 50%    28.00000  28529.657200  34689.003700   16932.546528  1.010054e+07
# 75%    41.50000  32091.716150  40147.767300   22021.754793  1.665223e+07
# max    55.00000  50424.792300  48594.635600  111546.683409  6.974830e+07
#
#         resale_price   popdensity
# count      24.000000    24.000000
# mean   443673.120000   442.052133
# std     79019.319243   283.013010
# min    355000.000000    28.865979
# 25%    390000.000000   256.758958
# 50%    419000.000000   361.596444
# 75%    463750.000000   546.348727
# ...

# %%
colors = 9
cmap = 'viridis'
figsize = (16, 10)
# year = '2016'
# cols = ['Country Name', 'Country Code', year]
#title = 'Individuals using the Internet (% of population) in {}'.format(year)merged.describe()

ax.set_title("Towns of Singapore by House Resale Price", fontdict={'fontsize': 20}, loc='left')
ax.set_axis_off()

ax = merged.dropna().plot(column='resale_price', cmap=cmap, figsize=figsize, scheme='equal_interval', k=colors, legend=True)
merged[merged.isnull().any(axis=1)].plot(ax=ax, color='#fafafa', hatch='///', )
ax.get_legend().set_bbox_to_anchor((.85, .4))
#gdf.plot(ax, marker='*', color='yellow', markersize=15)

# %%
colors = 9
cmap = 'viridis_r'
figsize = (16, 10)
# year = '2016'
# cols = ['Country Name', 'Country Code', year]
#title = 'Individuals using the Internet (% of population) in {}'.format(year)merged.describe()

ax = merged.dropna().plot(column='popdensity', cmap=cmap, figsize=figsize, scheme='equal_interval', k=colors, legend=True)
merged[merged.isnull().any(axis=1)].plot(ax=ax, color='#fafafa', hatch='///', )
ax.get_legend().set_bbox_to_anchor((.85, .4))
#gdf.plot(ax, marker='*', color='yellow', markersize=15)

# %%
merged
# Out:
#     OBJECTID     PLN_AREA_N PLN_AREA_C CA_IND           REGION_N REGION_C  \
# 0          1         BISHAN         BS      N     CENTRAL REGION       CR
# 1          2    BUKIT BATOK         BK      N        WEST REGION       WR
# 2          3    BUKIT MERAH         BM      N     CENTRAL REGION       CR
# 3          4  BUKIT PANJANG         BP      N        WEST REGION       WR
# 4          5    BUKIT TIMAH         BT      N     CENTRAL REGION       CR
# 5          9  CHOA CHU KANG         CK      N        WEST REGION       WR
# 6         10       CLEMENTI         CL      N        WEST REGION       WR
# 7         11        GEYLANG         GL      N     CENTRAL REGION       CR
# 8         13      PASIR RIS         PR      N        EAST REGION       ER
# 9         16      SEMBAWANG         SB      N       NORTH REGION       NR
# 10        17          BEDOK         BD      N        EAST REGION       ER
# 11        19       SENGKANG         SE      N  NORTH-EAST REGION      NER
# ...

# %%
metros = [2,6,2,5,6,3,6,0,3,1,8,3,2,3,10,0,1,1,8,1,2,3,6,7,3,2]
mapdf['mrts'] = metros
mapdf['mrtrate'] = mapdf.mrts*10000.0/mapdf.residential_land_area
mapdf
# Out:
#                town  resale_price   popdensity  residential_land_area  mrts  \
# 0        ANG MO KIO     371000.00   750.500000                  480.0     2
# 1             BEDOK     388000.00   504.271357                  549.0     6
# 2            BISHAN     589444.00   165.491184                  422.0     2
# 3       BUKIT BATOK     375000.00   540.952381                  480.0     5
# 4       BUKIT MERAH     560000.00   369.346734                  549.0     6
# 5     BUKIT PANJANG     420000.00   478.629032                  397.0     3
# 6       BUKIT TIMAH     699000.00    28.865979                  480.0     6
# 7      CENTRAL AREA     502000.00   162.380952                  219.0     0
# 8     CHOA CHU KANG     408710.88   385.406699                  500.0     3
# 9          CLEMENTI     408000.00   232.573290                  525.0     1
# 10          GEYLANG     370000.00   225.358852                  439.0     8
# ...

# %%
plt.scatter(mapdf.resale_price,mapdf.mrts)

# %%
plt.scatter(mapdf['resale_price'],mapdf['mrtrate'])

# %% [markdown]
# ### Which are the planning areas with 0 metros? How come they are priced high enough?
#
# ### There does not seem to be much correlation

# %% [markdown]
# #### Answer: Central Water Catchment Area & Marine Parade

# %% [markdown]
# ## Looking at trends in time / year

# %%
checkdf2.head(5)
# Out:
#   block      flat_model flat_type  floor_area_sqm  lease_commence_date  \
# 0   172        Improved    2 ROOM            45.0                 1986
# 1   510        Improved    2 ROOM            44.0                 1980
# 2   610  New Generation    3 ROOM            68.0                 1980
# 3   474  New Generation    3 ROOM            67.0                 1984
# 4   604  New Generation    3 ROOM            67.0                 1980
#
#        month  remaining_lease  resale_price storey_range        street_name  \
# 0 2012-03-01              NaN      250000.0     06 TO 10   ANG MO KIO AVE 4
# 1 2012-03-01              NaN      265000.0     01 TO 05   ANG MO KIO AVE 8
# 2 2012-03-01              NaN      315000.0     06 TO 10   ANG MO KIO AVE 4
# 3 2012-03-01              NaN      320000.0     01 TO 05  ANG MO KIO AVE 10
# 4 2012-03-01              NaN      321000.0     06 TO 10   ANG MO KIO AVE 5
#
#          town  month_number month_name  year  bedrooms  bathrooms  population  \
# ...

# %%
plt.scatter(checkdf2.year,checkdf2.resale_price)

# %%
checkdf2.flat_type.unique()
# Out:
# array(['2 ROOM', '3 ROOM', '4 ROOM', '5 ROOM', 'EXECUTIVE',
#        'MULTI-GENERATION', '1 ROOM'], dtype=object)

# %%
#fig, ax = plt.subplots()
#fig.set_size_inches(11.7, 8.27)

sns.lmplot( x="year", y="resale_price", data=checkdf2, fit_reg=True, hue='flat_type', legend=True)
 
# Move the legend to an empty part of the plot
#plt.legend(loc='lower right')

# %% [markdown]
# #### There seems to be a slight downward linear trend in house prices for the same kind of flat.

# %% [markdown]
# ### So far, I've been only looking at data from 2012 to 2018. Combining all 4 datasets for analysis from here on.

# %%
df1999.dtypes
# Out:
# month                   object
# town                    object
# flat_type               object
# block                   object
# street_name             object
# storey_range            object
# floor_area_sqm         float64
# flat_model              object
# lease_commence_date      int64
# resale_price             int64
# dtype: object

# %%
df2012.dtypes
# Out:
# month                   object
# town                    object
# flat_type               object
# block                   object
# street_name             object
# storey_range            object
# floor_area_sqm         float64
# flat_model              object
# lease_commence_date      int64
# resale_price           float64
# dtype: object

# %%
df2014.dtypes
# Out:
# month                   object
# town                    object
# flat_type               object
# block                   object
# street_name             object
# storey_range            object
# floor_area_sqm         float64
# flat_model              object
# lease_commence_date      int64
# resale_price           float64
# dtype: object

# %%
df2012.head(5)
# Out:
#      month        town flat_type block       street_name storey_range  \
# 0  2000-01  ANG MO KIO    3 ROOM   216  ANG MO KIO AVE 1     07 TO 09
# 1  2000-01  ANG MO KIO    3 ROOM   215  ANG MO KIO AVE 1     07 TO 09
# 2  2000-01  ANG MO KIO    3 ROOM   218  ANG MO KIO AVE 1     07 TO 09
# 3  2000-01  ANG MO KIO    4 ROOM   304  ANG MO KIO AVE 1     04 TO 06
# 4  2000-01  ANG MO KIO    5 ROOM   221  ANG MO KIO AVE 1     10 TO 12
#
#    floor_area_sqm      flat_model  lease_commence_date  resale_price
# 0            73.0  New Generation                 1976      159000.0
# 1            73.0  New Generation                 1976      167000.0
# 2            67.0  New Generation                 1976      163000.0
# 3            97.0  New Generation                 1977      260000.0
# 4           127.0        Improved                 1993      408000.0

# %%
df1999.head(5)
# Out:
#      month        town flat_type block       street_name storey_range  \
# 0  1990-01  ANG MO KIO    1 ROOM   309  ANG MO KIO AVE 1     10 TO 12
# 1  1990-01  ANG MO KIO    1 ROOM   309  ANG MO KIO AVE 1     04 TO 06
# 2  1990-01  ANG MO KIO    1 ROOM   309  ANG MO KIO AVE 1     10 TO 12
# 3  1990-01  ANG MO KIO    1 ROOM   309  ANG MO KIO AVE 1     07 TO 09
# 4  1990-01  ANG MO KIO    3 ROOM   216  ANG MO KIO AVE 1     04 TO 06
#
#    floor_area_sqm      flat_model  lease_commence_date  resale_price
# 0            31.0        IMPROVED                 1977          9000
# 1            31.0        IMPROVED                 1977          6000
# 2            31.0        IMPROVED                 1977          8000
# 3            31.0        IMPROVED                 1977          6000
# 4            73.0  NEW GENERATION                 1976         47200

# %%
df2018.head(5)
# Out:
#        month        town flat_type block        street_name storey_range  \
# 0 2015-01-01  ANG MO KIO    3 ROOM   174   ANG MO KIO AVE 4     07 TO 09
# 1 2015-01-01  ANG MO KIO    3 ROOM   541  ANG MO KIO AVE 10     01 TO 03
# 2 2015-01-01  ANG MO KIO    3 ROOM   163   ANG MO KIO AVE 4     01 TO 03
# 3 2015-01-01  ANG MO KIO    3 ROOM   446  ANG MO KIO AVE 10     01 TO 03
# 4 2015-01-01  ANG MO KIO    3 ROOM   557  ANG MO KIO AVE 10     07 TO 09
#
#    floor_area_sqm      flat_model  lease_commence_date  remaining_lease  \
# 0            60.0        Improved                 1986               70
# 1            68.0  New Generation                 1981               65
# 2            69.0  New Generation                 1980               64
# 3            68.0  New Generation                 1979               63
# 4            68.0  New Generation                 1980               64
#
#    resale_price  month_number month_name  year  bedrooms  bathrooms
# ...
